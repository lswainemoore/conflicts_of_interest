# %% [markdown]
# # Gather companies and bios for those companies
# ### Big picture:
# For companies gathered from http://www.nasdaq.com/screening/company-list.aspx, use stock ticker (and occasionally exchange name) to lookup SIC code, along with company profiles on Bloomberg, Google Finance, and Reuters.

# %% [markdown]
# ## Basic setup

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
from tqdm import tqdm, tqdm_notebook
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Make BS and requests play together a little more nicely

# %%
def get_soup(url, to = None):
    r = requests.get(url,timeout = to)
    soup = bs(r.text,'lxml')
    return soup

# %% [markdown]
# ## Import stock data

# %% [markdown]
# #### and add information about exchanges (here, labeled "Markets" -- probably not the technical term)

# %%
nasdaq = pd.read_csv("../data/SIC/nasdaq/nasdaq_from_nasdaq.csv")
nyse = pd.read_csv("../data/SIC/nasdaq/nyse_from_nasdaq.csv")
nasdaq['Market'] = 'NASDAQ'
nyse['Market'] = 'NYSE'
both = pd.concat([nasdaq, nyse])

# %% [markdown]
# ## Functions that gather info based on stock symbol

# %% [markdown]
# #### Lookup SIC code on EDGAR
# (adapted from https://mktstk.com/2015/03/03/sic-lookup-by-stock-symbol/)

# %%
def lookup_sic_code(symbol):
    url = "https://www.sec.gov/cgi-bin/browse-edgar?CIK=" + symbol.upper() + "&owner=exclude&action=getcompany&Find=Search"
    try:
        soup = get_soup(url)
        return int(soup.find('acronym', {'title' : 'Standard Industrial Code'}).findNextSibling("a").contents[0])
    except:
        return None

# %% [markdown]
# #### Lookup profile on Bloomberg
# Example: https://www.bloomberg.com/quote/NFLX:US

# %%
def lookup_bloomberg_profile(symbol):
    url = "https://www.bloomberg.com/quote/" + symbol.upper() + ":US"
    try:
        soup = get_soup(url)
        return str(soup.find('div',{'class' : 'profile__description'}).contents[0])
    except:
        return None

# %% [markdown]
# #### Lookup profile on Google Finance
# Example: https://www.google.com/finance?q=NASDAQ%3ANFLX
#
# (needs info about exchange)

# %%
def lookup_google_profile(symbol, exchange):
    url = "https://www.google.com/finance?q=" + exchange + "%3A" + symbol.upper()
    try: 
        soup = get_soup(url)
        return str(soup.find('div', {'class' : 'companySummary'}).contents[0])
    except:
        return None
    return description

# %% [markdown]
# #### Lookup profile on Reuters
# Example: http://www.reuters.com/finance/stocks/companyProfile?rpc=66&symbol=NFLX.O

# %%
# seems to not need exchange...can figure it out mostly
# though it's possible I'm mistaken about this
def lookup_reuters_profile(symbol):
    url = "http://www.reuters.com/finance/stocks/companyProfile?symbol=" + symbol.upper()
    try: 
        soup = get_soup(url)
        paragraphs = soup.find('div', {'id' : 'companyNews'}).findAll('p')
        return str('\n'.join([(lambda x: x.contents[0] if len(x.contents)>0 else '')(p) for p in paragraphs]))
    except:
        return None

# %% [markdown]
# ## Actually gather the information using apply statements
# #### writing updated dataframes to temp file in between calls
# #### tqdm makes this a lot less painful, because can see progress
# See:
#
# http://stackoverflow.com/questions/40476680/how-to-use-tqdm-with-pandas-in-a-jupyter-notebook
#
# http://stackoverflow.com/questions/18603270/progress-indicator-during-pandas-operations-python
#
# https://pypi.python.org/pypi/tqdm

# %%
tqdm_notebook().pandas()
both['SIC'] = both.progress_apply(lambda row: lookup_sic_code(row['Symbol']), axis=1)
both.to_csv("tmp/TEMP_BOTH.csv")

# %%
tqdm_notebook().pandas()
both['bloomberg'] = both.progress_apply(lambda row: lookup_bloomberg_profile(row['Symbol']), axis=1)
both.to_csv("tmp/TEMP_BOTH.csv")

# %%
tqdm_notebook().pandas()
both['google'] = both.progress_apply(lambda row: lookup_google_profile(row['Symbol'], row["Market"]), axis=1)
both.to_csv("tmp/TEMP_BOTH.csv")

# %%
tqdm_notebook().pandas()
both['reuters'] = both.progress_apply(lambda row: lookup_reuters_profile(row['Symbol']), axis=1)
both.to_csv("tmp/TEMP_BOTH.csv")

# %% [markdown]
# ## Joining to OpenSecrets categories/sectors/industries
# #### Using tables from:
# * https://groups.google.com/forum/#!topic/opensecrets-open-data/nXYSeFrtwxk
# * https://www.opensecrets.org/downloads/crp/CRP_Categories.txt (with its header removed)

# %%
sic2crpcat = pd.read_csv("../data/SIC/conversion/SIC2CRPCat.csv")
crp_cats = pd.read_csv("../data/SIC/CRP_Categories_no_head.txt", sep = "\t")

# %%
both_joined = pd.merge(left = both, right = sic2crpcat, left_on='SIC', right_on='SICcode', how='left')
both_joined = pd.merge(left = both_joined, right = crp_cats, on="Catcode", how='left')

# %%
both_joined_raw
# Out:
#      Symbol                                         Name LastSale MarketCap  \
# 0       PIH       1347 Property Insurance Holdings, Inc.      7.5   $44.68M
# 1      TURN                     180 Degree Capital Corp.     1.43   $44.19M
# 2      FLWS                      1-800 FLOWERS.COM, Inc.       10  $655.69M
# 3      FCCY                1st Constitution Bancorp (NJ)    17.85  $143.29M
# 4      SRCE                       1st Source Corporation    44.55     $1.2B
# 5      VNET                         21Vianet Group, Inc.     5.55  $628.87M
# 6      TWOU                                     2U, Inc.    41.72    $1.97B
# 7      JOBS                                  51job, Inc.    38.07    $2.29B
# 8      CAFD                   8point3 Energy Partners LP    12.22  $966.32M
# 9      EGHT                                      8x8 Inc    14.95    $1.36B
# 10     AVHI                              A V Homes, Inc.    16.65   $374.8M
# 11     SHLM                            A. Schulman, Inc.     29.3  $863.97M
# 12     AAON                                   AAON, Inc.    34.65    $1.82B
# 13     ABAX                                 ABAXIS, Inc.    47.46    $1.07B
# 14     ABEO                     Abeona Therapeutics Inc.     4.95  $199.26M
# 15    ABEOW                     Abeona Therapeutics Inc.   2.6999       n/a
# 16     ABIL                                 Ability Inc.     1.21   $31.16M
# 17     ABMD                                ABIOMED, Inc.   120.73    $5.26B
# 18     AXAS                Abraxas Petroleum Corporation    1.985  $325.23M
# 19     ACIU                                 AC Immune SA    10.01  $569.79M
# 20     ACIA                  Acacia Communications, Inc.     54.3    $2.09B
# 21     ACTG                  Acacia Research Corporation     5.05  $254.86M
# 22     ACHC              Acadia Healthcare Company, Inc.     42.9    $3.77B
# 23     ACAD                  ACADIA Pharmaceuticals Inc.    33.37    $4.05B
# 24     ACST                          Acasti Pharma, Inc.     1.32   $19.41M
# 25     AXDX                 Accelerate Diagnostics, Inc.    23.15     $1.2B
# 26     XLRN                        Acceleron Pharma Inc.    28.76    $1.11B
# 27     ANCX                  Access National Corporation    27.56  $296.73M
# 28     ARAY                         Accuray Incorporated     4.65  $385.47M
# 29     ACRX                 AcelRx Pharmaceuticals, Inc.     2.75  $124.68M
# ...     ...                                          ...      ...       ...
# 6285    XEL                             Xcel Energy Inc.    45.08   $22.89B
# 6286    XHR                 Xenia Hotels & Resorts, Inc.    17.27    $1.85B
# 6287    XRM                    Xerium Technologies, Inc.     6.51  $105.16M
# 6288    XRX                            Xerox Corporation     7.02    $7.14B
# 6289    XIN                   Xinyuan Real Estate Co Ltd     4.43  $291.11M
# 6290     XL                                XL Group Ltd.    40.67   $10.82B
# 6291   XOXO                               XO Group, Inc.    17.24  $450.88M
# 6292    XPO                          XPO Logistics, Inc.    45.75     $5.1B
# 6293    XYL                                   Xylem Inc.    49.46    $8.89B
# 6294    AUY                             Yamana Gold Inc.     3.15    $2.99B
# 6295   YELP                                    Yelp Inc.    32.69     $2.6B
# 6296   YEXT                                   Yext, Inc.    13.55    $1.16B
# 6297    YGE  Yingli Green Energy Holding Company Limited     2.83   $51.44M
# 6298    YRD                                Yirendai Ltd.    23.92     $1.4B
# 6299    YPF                         YPF Sociedad Anonima    26.16   $10.29B
# 6300   YUMC                     Yum China Holdings, Inc.    32.94   $12.66B
# 6301    YUM                            Yum! Brands, Inc.    63.89   $22.51B
# 6302   YUME                                   YuMe, Inc.     3.87  $131.73M
# 6303   ZAYO                    Zayo Group Holdings, Inc.    34.76    $8.49B
# 6304    ZEN                                Zendesk, Inc.    28.41     $2.8B
# 6305   ZPIN                              Zhaopin Limited    17.89  $997.73M
# 6306    ZBH                 Zimmer Biomet Holdings, Inc.   121.16   $24.38B
# 6307   ZB^A                         Zions Bancorporation   24.239       n/a
# 6308   ZB^F                         Zions Bancorporation    25.49       n/a
# 6309   ZB^G                         Zions Bancorporation    28.31       n/a
# 6310   ZB^H                         Zions Bancorporation  25.3454       n/a
# 6311    ZBK                         Zions Bancorporation  28.9268       n/a
# 6312   ZOES                      Zoe&#39;s Kitchen, Inc.    17.03  $331.78M
# 6313    ZTS                                  Zoetis Inc.     53.5    $26.3B
# 6314    ZTO                    ZTO Express (Cayman) Inc.    13.02    $9.52B
#
#      IPOyear           Sector_x  \
# 0       2014            Finance
# 1        n/a            Finance
# 2       1999  Consumer Services
# 3        n/a            Finance
# 4        n/a            Finance
# 5       2011         Technology
# 6       2014         Technology
# 7       2004         Technology
# 8       2015   Public Utilities
# 9        n/a   Public Utilities
# 10       n/a      Capital Goods
# 11      1972   Basic Industries
# 12       n/a      Capital Goods
# 13      1992      Capital Goods
# 14       n/a        Health Care
# 15       n/a        Health Care
# 16      2014            Finance
# 17       n/a        Health Care
# 18       n/a             Energy
# 19      2016        Health Care
# 20      2016         Technology
# 21       n/a      Miscellaneous
# 22       n/a        Health Care
# 23      1985        Health Care
# 24       n/a        Health Care
# 25       n/a      Capital Goods
# 26      2013        Health Care
# 27       n/a            Finance
# 28      2007        Health Care
# 29      2011        Health Care
# ...      ...                ...
# 6285     n/a   Public Utilities
# 6286    2015  Consumer Services
# 6287    2005   Basic Industries
# 6288     n/a      Miscellaneous
# 6289    2007   Basic Industries
# 6290     n/a            Finance
# 6291     n/a  Consumer Services
# 6292     n/a  Consumer Services
# 6293    2011      Capital Goods
# 6294     n/a   Basic Industries
# 6295    2012  Consumer Services
# 6296    2017                n/a
# 6297    2007         Technology
# 6298    2015            Finance
# 6299    1993             Energy
# 6300    2016  Consumer Services
# 6301     n/a  Consumer Services
# 6302    2013         Technology
# 6303    2014   Public Utilities
# 6304    2014         Technology
# 6305    2014         Technology
# 6306     n/a        Health Care
# 6307     n/a                n/a
# 6308     n/a                n/a
# 6309     n/a                n/a
# 6310     n/a                n/a
# 6311     n/a            Finance
# 6312    2014  Consumer Services
# 6313    2013        Health Care
# 6314    2016     Transportation
#
#                                                industry  \
# 0                            Property-Casualty Insurers
# 1                            Finance/Investors Services
# 2                                Other Specialty Stores
# 3                                  Savings Institutions
# 4                                           Major Banks
# 5       Computer Software: Programming, Data Processing
# 6               Computer Software: Prepackaged Software
# 7                       Diversified Commercial Services
# 8                           Electric Utilities: Central
# 9                          Telecommunications Equipment
# 10                                         Homebuilding
# 11                                      Major Chemicals
# 12                      Industrial Machinery/Components
# 13                      Industrial Machinery/Components
# 14                                Major Pharmaceuticals
# 15                                Major Pharmaceuticals
# 16                                    Business Services
# 17                           Medical/Dental Instruments
# 18                                 Oil & Gas Production
# 19                                Major Pharmaceuticals
# 20                                       Semiconductors
# 21                               Multi-Sector Companies
# 22                                 Medical Specialities
# 23                                Major Pharmaceuticals
# 24                                Major Pharmaceuticals
# 25     Biotechnology: Laboratory Analytical Instruments
# 26    Biotechnology: Biological Products (No Diagnos...
# 27                                 Savings Institutions
# 28                           Medical/Dental Instruments
# 29                                Major Pharmaceuticals
# ...                                                 ...
# 6285                                   Power Generation
# 6286                                     Hotels/Resorts
# 6287                                           Textiles
# 6288                                  Business Services
# 6289                                       Homebuilding
# 6290                         Property-Casualty Insurers
# 6291                            Other Consumer Services
# 6292                            Transportation Services
# 6293                                     Fluid Controls
# 6294                                    Precious Metals
# 6295                            Other Consumer Services
# 6296                                                n/a
# 6297                                     Semiconductors
# 6298                         Finance: Consumer Services
# 6299                           Integrated oil Companies
# 6300                                        Restaurants
# 6301                                        Restaurants
# 6302                                        Advertising
# 6303                       Telecommunications Equipment
# 6304                                       EDP Services
# 6305                              Professional Services
# 6306                             Industrial Specialties
# 6307                                                n/a
# 6308                                                n/a
# 6309                                                n/a
# 6310                                                n/a
# 6311                                        Major Banks
# 6312                                        Restaurants
# 6313                              Major Pharmaceuticals
# 6314                  Trucking Freight/Courier Services
#
#                            Summary Quote  Unnamed: 8  Market  \
# 0       http://www.nasdaq.com/symbol/pih         NaN  NASDAQ
# 1      http://www.nasdaq.com/symbol/turn         NaN  NASDAQ
# 2      http://www.nasdaq.com/symbol/flws         NaN  NASDAQ
# 3      http://www.nasdaq.com/symbol/fccy         NaN  NASDAQ
# 4      http://www.nasdaq.com/symbol/srce         NaN  NASDAQ
# 5      http://www.nasdaq.com/symbol/vnet         NaN  NASDAQ
# 6      http://www.nasdaq.com/symbol/twou         NaN  NASDAQ
# 7      http://www.nasdaq.com/symbol/jobs         NaN  NASDAQ
# 8      http://www.nasdaq.com/symbol/cafd         NaN  NASDAQ
# 9      http://www.nasdaq.com/symbol/eght         NaN  NASDAQ
# 10     http://www.nasdaq.com/symbol/avhi         NaN  NASDAQ
# 11     http://www.nasdaq.com/symbol/shlm         NaN  NASDAQ
# 12     http://www.nasdaq.com/symbol/aaon         NaN  NASDAQ
# 13     http://www.nasdaq.com/symbol/abax         NaN  NASDAQ
# 14     http://www.nasdaq.com/symbol/abeo         NaN  NASDAQ
# 15    http://www.nasdaq.com/symbol/abeow         NaN  NASDAQ
# 16     http://www.nasdaq.com/symbol/abil         NaN  NASDAQ
# 17     http://www.nasdaq.com/symbol/abmd         NaN  NASDAQ
# 18     http://www.nasdaq.com/symbol/axas         NaN  NASDAQ
# 19     http://www.nasdaq.com/symbol/aciu         NaN  NASDAQ
# 20     http://www.nasdaq.com/symbol/acia         NaN  NASDAQ
# 21     http://www.nasdaq.com/symbol/actg         NaN  NASDAQ
# 22     http://www.nasdaq.com/symbol/achc         NaN  NASDAQ
# 23     http://www.nasdaq.com/symbol/acad         NaN  NASDAQ
# 24     http://www.nasdaq.com/symbol/acst         NaN  NASDAQ
# 25     http://www.nasdaq.com/symbol/axdx         NaN  NASDAQ
# 26     http://www.nasdaq.com/symbol/xlrn         NaN  NASDAQ
# 27     http://www.nasdaq.com/symbol/ancx         NaN  NASDAQ
# 28     http://www.nasdaq.com/symbol/aray         NaN  NASDAQ
# 29     http://www.nasdaq.com/symbol/acrx         NaN  NASDAQ
# ...                                  ...         ...     ...
# 6285    http://www.nasdaq.com/symbol/xel         NaN    NYSE
# 6286    http://www.nasdaq.com/symbol/xhr         NaN    NYSE
# 6287    http://www.nasdaq.com/symbol/xrm         NaN    NYSE
# 6288    http://www.nasdaq.com/symbol/xrx         NaN    NYSE
# 6289    http://www.nasdaq.com/symbol/xin         NaN    NYSE
# 6290     http://www.nasdaq.com/symbol/xl         NaN    NYSE
# 6291   http://www.nasdaq.com/symbol/xoxo         NaN    NYSE
# 6292    http://www.nasdaq.com/symbol/xpo         NaN    NYSE
# 6293    http://www.nasdaq.com/symbol/xyl         NaN    NYSE
# 6294    http://www.nasdaq.com/symbol/auy         NaN    NYSE
# 6295   http://www.nasdaq.com/symbol/yelp         NaN    NYSE
# 6296   http://www.nasdaq.com/symbol/yext         NaN    NYSE
# 6297    http://www.nasdaq.com/symbol/yge         NaN    NYSE
# 6298    http://www.nasdaq.com/symbol/yrd         NaN    NYSE
# 6299    http://www.nasdaq.com/symbol/ypf         NaN    NYSE
# 6300   http://www.nasdaq.com/symbol/yumc         NaN    NYSE
# 6301    http://www.nasdaq.com/symbol/yum         NaN    NYSE
# 6302   http://www.nasdaq.com/symbol/yume         NaN    NYSE
# 6303   http://www.nasdaq.com/symbol/zayo         NaN    NYSE
# 6304    http://www.nasdaq.com/symbol/zen         NaN    NYSE
# 6305   http://www.nasdaq.com/symbol/zpin         NaN    NYSE
# 6306    http://www.nasdaq.com/symbol/zbh         NaN    NYSE
# 6307   http://www.nasdaq.com/symbol/zb^a         NaN    NYSE
# 6308   http://www.nasdaq.com/symbol/zb^f         NaN    NYSE
# 6309   http://www.nasdaq.com/symbol/zb^g         NaN    NYSE
# 6310   http://www.nasdaq.com/symbol/zb^h         NaN    NYSE
# 6311    http://www.nasdaq.com/symbol/zbk         NaN    NYSE
# 6312   http://www.nasdaq.com/symbol/zoes         NaN    NYSE
# 6313    http://www.nasdaq.com/symbol/zts         NaN    NYSE
# 6314    http://www.nasdaq.com/symbol/zto         NaN    NYSE
#
#                     ...                 SICcode Catcode  \
# 0                   ...                    6331   F3400
# 1                   ...                     NaN     NaN
# 2                   ...                     NaN     NaN
# 3                   ...                    6035   F1200
# 4                   ...                    6022   F1100
# 5                   ...                     NaN     NaN
# 6                   ...                    7372   C5120
# 7                   ...                    7361   G5250
# 8                   ...                    4911   E1600
# 9                   ...                    4813   C4100
# 10                  ...                    1531   B2000
# 11                  ...                    2821   M1500
# 12                  ...                    3585   M2300
# 13                  ...                    3829   M9000
# 14                  ...                    2834   H4300
# 15                  ...                    2834   H4300
# 16                  ...                    3669   C4600
# 17                  ...                    3841   H4100
# 18                  ...                    1311   E1120
# 19                  ...                    2834   H4300
# 20                  ...                    3674   C5110
# 21                  ...                    6794     NaN
# 22                  ...                    8093   H3200
# 23                  ...                    2834   H4300
# 24                  ...                    2834   H4300
# 25                  ...                    3826   M9000
# 26                  ...                    2836   H4300
# 27                  ...                    6035   F1200
# 28                  ...                    3841   H4100
# 29                  ...                    2834   H4300
# ...                 ...                     ...     ...
# 6285                ...                    4931   E1620
# 6286                ...                    7011   T9100
# 6287                ...                    2221   M1400
# 6288                ...                    7389   G5200
# 6289                ...                     NaN     NaN
# 6290                ...                    6331   F3400
# 6291                ...                     NaN     NaN
# 6292                ...                     NaN     NaN
# 6293                ...                    3561   M2300
# 6294                ...                     NaN     NaN
# 6295                ...                     NaN     NaN
# 6296                ...                     NaN     NaN
# 6297                ...                    3674   C5110
# 6298                ...                     NaN     NaN
# 6299                ...                    2911   E1160
# 6300                ...                    5812   G2900
# 6301                ...                    5812   G2900
# 6302                ...                    7311   G5210
# 6303                ...                    4813   C4100
# 6304                ...                    7374   C5130
# 6305                ...                    7363   G5250
# 6306                ...                    3842   H4100
# 6307                ...                     NaN     NaN
# 6308                ...                     NaN     NaN
# 6309                ...                     NaN     NaN
# 6310                ...                     NaN     NaN
# 6311                ...                    6021   F1100
# 6312                ...                    5812   G2900
# 6313                ...                    2834   H4300
# 6314                ...                     NaN     NaN
#
#                                               Category  \
# 0                        Property & casualty insurance
# 1                                                  NaN
# 2                                                  NaN
# 3                    Savings banks & Savings and Loans
# 4            Commercial banks & bank holding companies
# 5                                                  NaN
# 6                                    Computer software
# 7                                  Employment agencies
# 8                             Electric Power utilities
# 9                                  Telephone utilities
# 10                            Residential construction
# 11             Plastics & Rubber processing & products
# 12         Industrial/commercial equipment & materials
# 13                               Precision instruments
# 14                        Pharmaceutical manufacturing
# 15                        Pharmaceutical manufacturing
# 16                Telephone & communications equipment
# 17              Medical supplies manufacturing & sales
# 18                     Independent oil & gas producers
# 19                        Pharmaceutical manufacturing
# 20                 Computers, components & accessories
# 21                                                 NaN
# 22    Outpatient health services (incl drug & alcohol)
# 23                        Pharmaceutical manufacturing
# 24                        Pharmaceutical manufacturing
# 25                               Precision instruments
# 26                        Pharmaceutical manufacturing
# 27                   Savings banks & Savings and Loans
# 28              Medical supplies manufacturing & sales
# 29                        Pharmaceutical manufacturing
# ...                                                ...
# 6285                          Gas & Electric Utilities
# 6286                                   Hotels & motels
# 6287                                    Manmade fibers
# 6288                                 Business services
# 6289                                               NaN
# 6290                     Property & casualty insurance
# 6291                                               NaN
# 6292                                               NaN
# 6293       Industrial/commercial equipment & materials
# 6294                                               NaN
# 6295                                               NaN
# 6296                                               NaN
# 6297               Computers, components & accessories
# 6298                                               NaN
# 6299                    Petroleum refining & marketing
# 6300             Restaurants & drinking establishments
# 6301             Restaurants & drinking establishments
# 6302           Advertising & public relations services
# 6303                               Telephone utilities
# 6304               Data processing & computer services
# 6305                               Employment agencies
# 6306            Medical supplies manufacturing & sales
# 6307                                               NaN
# 6308                                               NaN
# 6309                                               NaN
# 6310                                               NaN
# 6311         Commercial banks & bank holding companies
# 6312             Restaurants & drinking establishments
# 6313                      Pharmaceutical manufacturing
# 6314                                               NaN
#
#                                    SICname  MultSIC  \
# 0     Fire, marine, and casualty insurance      NaN
# 1                                      NaN      NaN
# 2                                      NaN      NaN
# 3             Federal savings institutions        X
# 4                   State commercial banks        X
# 5                                      NaN      NaN
# 6                     Prepackaged software      NaN
# 7                      Employment agencies        X
# 8                        Electric services      NaN
# 9      Telephone communications, exc radio        X
# 10                      Operative builders        X
# 11           Plastics materials and resins        X
# 12     Refrigeration and heating equipment        X
# 13    Measuring & controlling devices, NEC        X
# 14             Pharmaceutical preparations        X
# 15             Pharmaceutical preparations        X
# 16           Communications equipment, NEC        X
# 17        Surgical and medical instruments        X
# 18         Crude petroleum and natural gas        X
# 19             Pharmaceutical preparations        X
# 20      Semiconductors and related devices        X
# 21               Patent owners and lessors        X
# 22    Specialty outpatient facilities, NEC        X
# 23             Pharmaceutical preparations        X
# 24             Pharmaceutical preparations        X
# 25                  Analytical instruments        X
# 26     Biological products, exc diagnostic        X
# 27            Federal savings institutions        X
# 28        Surgical and medical instruments        X
# 29             Pharmaceutical preparations        X
# ...                                    ...      ...
# 6285  Electric and other services combined        X
# 6286                     Hotels and motels        X
# 6287      Broadwoven fabric mills, manmade        X
# 6288                Business services, NEC        X
# 6289                                   NaN      NaN
# 6290  Fire, marine, and casualty insurance      NaN
# 6291                                   NaN      NaN
# 6292                                   NaN      NaN
# 6293           Pumps and pumping equipment        X
# 6294                                   NaN      NaN
# 6295                                   NaN      NaN
# 6296                                   NaN      NaN
# 6297    Semiconductors and related devices        X
# 6298                                   NaN      NaN
# 6299                    Petroleum refining        X
# 6300                         Eating places        X
# 6301                         Eating places        X
# 6302                  Advertising agencies        X
# 6303   Telephone communications, exc radio        X
# 6304       Data processing and preparation        X
# 6305                  Help supply services        X
# 6306      Surgical appliances and supplies        X
# 6307                                   NaN      NaN
# 6308                                   NaN      NaN
# 6309                                   NaN      NaN
# 6310                                   NaN      NaN
# 6311             National commercial banks        X
# 6312                         Eating places        X
# 6313           Pharmaceutical preparations        X
# 6314                                   NaN      NaN
#
#                                                Catname Catorder  \
# 0                        Property & casualty insurance      F09
# 1                                                  NaN      NaN
# 2                                                  NaN      NaN
# 3                    Savings banks & Savings and Loans      F04
# 4            Commercial banks & bank holding companies      F03
# 5                                                  NaN      NaN
# 6                                    Computer software      B12
# 7                                  Employment agencies      N05
# 8                             Electric Power utilities      E08
# 9                                  Telephone utilities      B08
# 10                            Residential construction      C02
# 11             Plastics & Rubber processing & products      N13
# 12         Industrial/commercial equipment & materials      N15
# 13                               Precision instruments      N15
# 14                        Pharmaceutical manufacturing      H04
# 15                        Pharmaceutical manufacturing      H04
# 16                       Other Communications Services      B09
# 17                          Medical Devices & Supplies      H04
# 18                     Independent oil & gas producers      E01
# 19                        Pharmaceutical manufacturing      H04
# 20                   Computer components & accessories      B12
# 21                                                 NaN      NaN
# 22    Outpatient health services (incl drug & alcohol)      H03
# 23                        Pharmaceutical manufacturing      H04
# 24                        Pharmaceutical manufacturing      H04
# 25                               Precision instruments      N15
# 26                        Pharmaceutical manufacturing      H04
# 27                   Savings banks & Savings and Loans      F04
# 28                          Medical Devices & Supplies      H04
# 29                        Pharmaceutical manufacturing      H04
# ...                                                ...      ...
# 6285                          Gas & Electric Utilities      E08
# 6286                                   Hotels & motels      N08
# 6287                                    Manmade fibers      N15
# 6288                                 Business services      N05
# 6289                                               NaN      NaN
# 6290                     Property & casualty insurance      F09
# 6291                                               NaN      NaN
# 6292                                               NaN      NaN
# 6293       Industrial/commercial equipment & materials      N15
# 6294                                               NaN      NaN
# 6295                                               NaN      NaN
# 6296                                               NaN      NaN
# 6297                 Computer components & accessories      B12
# 6298                                               NaN      NaN
# 6299                    Petroleum refining & marketing      E01
# 6300             Restaurants & drinking establishments      N01
# 6301             Restaurants & drinking establishments      N01
# 6302           Advertising & public relations services      N05
# 6303                               Telephone utilities      B08
# 6304               Data processing & computer services      B12
# 6305                               Employment agencies      N05
# 6306                        Medical Devices & Supplies      H04
# 6307                                               NaN      NaN
# 6308                                               NaN      NaN
# 6309                                               NaN      NaN
# 6310                                               NaN      NaN
# 6311         Commercial banks & bank holding companies      F03
# 6312             Restaurants & drinking establishments      N01
# 6313                      Pharmaceutical manufacturing      H04
# 6314                                               NaN      NaN
#
#                                Industry               Sector_y  \
# 0                             Insurance  Finance/Insur/RealEst
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
# 3                       Savings & Loans  Finance/Insur/RealEst
# 4                      Commercial Banks  Finance/Insur/RealEst
# 5                                   NaN                    NaN
# 6               Electronics Mfg & Equip   Communic/Electronics
# 7                     Business Services          Misc Business
# 8                    Electric Utilities    Energy/Nat Resource
# 9                   Telephone Utilities   Communic/Electronics
# 10                        Home Builders           Construction
# 11     Chemical & Related Manufacturing          Misc Business
# 12    Misc Manufacturing & Distributing          Misc Business
# 13    Misc Manufacturing & Distributing          Misc Business
# 14      Pharmaceuticals/Health Products                 Health
# 15      Pharmaceuticals/Health Products                 Health
# 16                     Telecom Services   Communic/Electronics
# 17      Pharmaceuticals/Health Products                 Health
# 18                            Oil & Gas    Energy/Nat Resource
# 19      Pharmaceuticals/Health Products                 Health
# 20              Electronics Mfg & Equip   Communic/Electronics
# 21                                  NaN                    NaN
# 22                 Health Services/HMOs                 Health
# 23      Pharmaceuticals/Health Products                 Health
# 24      Pharmaceuticals/Health Products                 Health
# 25    Misc Manufacturing & Distributing          Misc Business
# 26      Pharmaceuticals/Health Products                 Health
# 27                      Savings & Loans  Finance/Insur/RealEst
# 28      Pharmaceuticals/Health Products                 Health
# 29      Pharmaceuticals/Health Products                 Health
# ...                                 ...                    ...
# 6285                 Electric Utilities    Energy/Nat Resource
# 6286                    Lodging/Tourism          Misc Business
# 6287  Misc Manufacturing & Distributing          Misc Business
# 6288                  Business Services          Misc Business
# 6289                                NaN                    NaN
# 6290                          Insurance  Finance/Insur/RealEst
# 6291                                NaN                    NaN
# 6292                                NaN                    NaN
# 6293  Misc Manufacturing & Distributing          Misc Business
# 6294                                NaN                    NaN
# 6295                                NaN                    NaN
# 6296                                NaN                    NaN
# 6297            Electronics Mfg & Equip   Communic/Electronics
# 6298                                NaN                    NaN
# 6299                          Oil & Gas    Energy/Nat Resource
# 6300                    Food & Beverage          Misc Business
# 6301                    Food & Beverage          Misc Business
# 6302                  Business Services          Misc Business
# 6303                Telephone Utilities   Communic/Electronics
# 6304            Electronics Mfg & Equip   Communic/Electronics
# 6305                  Business Services          Misc Business
# 6306    Pharmaceuticals/Health Products                 Health
# 6307                                NaN                    NaN
# 6308                                NaN                    NaN
# 6309                                NaN                    NaN
# 6310                                NaN                    NaN
# 6311                   Commercial Banks  Finance/Insur/RealEst
# 6312                    Food & Beverage          Misc Business
# 6313    Pharmaceuticals/Health Products                 Health
# 6314                                NaN                    NaN
#
#                            Sector Long
# 0     Finance, Insurance & Real Estate
# 1                                  NaN
# 2                                  NaN
# 3     Finance, Insurance & Real Estate
# 4     Finance, Insurance & Real Estate
# 5                                  NaN
# 6           Communications/Electronics
# 7                        Misc Business
# 8           Energy & Natural Resources
# 9           Communications/Electronics
# 10                        Construction
# 11                       Misc Business
# 12                       Misc Business
# 13                       Misc Business
# 14                              Health
# 15                              Health
# 16          Communications/Electronics
# 17                              Health
# 18          Energy & Natural Resources
# 19                              Health
# 20          Communications/Electronics
# 21                                 NaN
# 22                              Health
# 23                              Health
# 24                              Health
# 25                       Misc Business
# 26                              Health
# 27    Finance, Insurance & Real Estate
# 28                              Health
# 29                              Health
# ...                                ...
# 6285        Energy & Natural Resources
# 6286                     Misc Business
# 6287                     Misc Business
# 6288                     Misc Business
# 6289                               NaN
# 6290  Finance, Insurance & Real Estate
# 6291                               NaN
# 6292                               NaN
# 6293                     Misc Business
# 6294                               NaN
# 6295                               NaN
# 6296                               NaN
# 6297        Communications/Electronics
# 6298                               NaN
# 6299        Energy & Natural Resources
# 6300                     Misc Business
# 6301                     Misc Business
# 6302                     Misc Business
# 6303        Communications/Electronics
# 6304        Communications/Electronics
# 6305                     Misc Business
# 6306                            Health
# 6307                               NaN
# 6308                               NaN
# 6309                               NaN
# 6310                               NaN
# 6311  Finance, Insurance & Real Estate
# 6312                     Misc Business
# 6313                            Health
# 6314                               NaN
#
# [6315 rows x 24 columns]

# %%
both_joined_raw = both_joined
both_joined_raw.to_csv('tmp/TEMP_both_joined_raw.csv')

# %% [markdown]
# ## Clean up the data a bit

# %%
# subset columns
both_joined_processed = both_joined.loc[:,['Symbol', 'Name', 'Market', 'SIC',
                                 'bloomberg','google','reuters','Catcode', 'Catname','Industry','Sector Long']]
# remove whitespace, and replace empty remaining strings with NaN (for whatever reason, 
# replacing with None fills with the value of row above)
both_joined_processed.bloomberg = both_joined_processed.bloomberg.str.strip().replace("",np.nan)
both_joined_processed.google = both_joined_processed.google.str.strip().replace("",np.nan)
both_joined_processed.reuters = both_joined_processed.reuters.str.strip().replace("",np.nan)
# remove rows that don't have SIC/Catcode/Catname (making sure joined properly)
# and rows that don't have at least one text column
both_joined_processed = both_joined_processed[(~(both_joined_processed.Catname.isnull())) & 
                                              (~(both_joined_processed.Catcode.isnull())) & 
                                              (~(both_joined_processed.SIC.isnull())) & 
                                              ((~(both_joined_processed.bloomberg.isnull())) | 
                                               (~(both_joined_processed.google.isnull())) | 
                                               (~(both_joined_processed.reuters.isnull()))
                                              )]

# %% [markdown]
# ## Write data

# %%
both_joined_processed.to_csv('../data/lincoln/companies_catcodes_text.csv',index=False)

# %%
len(both_joined_processed)
# Out:
# 3623

# %%
# # turns out this is a bit tricky
# def lookup_yahoo_profile(symbol):
#     return None
# #     s = Share(symbol)
# #     print(s.get_info())
# #     url = "http://finance.yahoo.com/quote/" + symbol + "/profile"
# #     r = requests.get(url)
# #     soup = bs(r.text,"lxml")
# #     description = soup.findAll('section', {'aria-label' : "Main Column"})[0].child
# #     print(description)
